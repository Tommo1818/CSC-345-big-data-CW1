# %% [markdown]
# Task 2.1:

# %% [markdown]
# The iris data is taken from the Fisher Iris Dataset. It contains sepal and petal length, width, and species of 150 flowers.

# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn.cluster as skcl
import sklearn.mixture as skmi

data = np.load('./Iris_data.npy')
labels = np.load('./Iris_labels.npy')

# Choose two features dimensions to plot, keeping it consistent for the notebook
x_feature = 0
y_feature = 1

# %%
plt.scatter(data[:,x_feature], data[:,y_feature], c=labels)
plt.title('Iris Data')
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.show()

# %% [markdown]
# Task 2.2:

# %% [markdown]
# The following code uses the kmeans method from the sklearn.cluster module to fit and predict the given number of clusters of the Fisher Iris Dataset, work out each cluster centre, and then show it on a scatter plot.

# %%
predicted_labels = skcl.KMeans(n_clusters=3).fit_predict(data)
plt.scatter(data[:,x_feature], data[:,y_feature], c=predicted_labels)
plt.title('Iris Data With KMeans Clustering')
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
# add the cluster centers to the plot
plt.scatter(skcl.KMeans(n_clusters=3).fit(data).cluster_centers_[:,x_feature], skcl.KMeans(n_clusters=3).fit(data).cluster_centers_[:,y_feature], c='red')
plt.show()
# Out:
# c:\Users\tvern\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\tvern\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\tvern\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %% [markdown]
# Task 2.3:

# %% [markdown]
# The following code uses the GMM clustering method from the sklearn.mixture module to fit and predict the clustering of the Fisher Iris Dataset, work out the gaussian means centres, and the show it in a plot.

# %%
dataGMM = skmi.GaussianMixture(n_components=3)
predicted_labelsGMM = dataGMM.fit_predict(data)
plt.scatter(data[:,x_feature], data[:,y_feature], c=predicted_labelsGMM)
plt.title('Iris Data With GMM Clustering')
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
# add the g gaussian means to the plot
plt.scatter(dataGMM.fit(data).means_[:,x_feature], dataGMM.fit(data).means_[:,y_feature], c='red')
plt.show()
# Out:
# c:\Users\tvern\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\tvern\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\tvern\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# The following predicts the posterior probabilities for the data points in Iris_data

# %%
# predict the posterior probabilities for the data points
probabilities = dataGMM.predict_proba(data)
# produce a scatter plot for each component of the gmm model
for i in range(3):
    plt.scatter(data[:,x_feature], data[:,y_feature], c=probabilities[:,i])
    plt.title('Component ' + str(i))
    plt.xlabel('Sepal length')
    plt.ylabel('Sepal width')
    # add a bar on the side
    plt.colorbar()
    plt.show()

# %% [markdown]
# Task 2.4:

# %% [markdown]
# start by printing the raw data, with each column against its ajacent column (three plots for 6 columns)

# %%
data2 = np.load('./task2_4.npy')
for i in range(3):
    print(i)
    plt.scatter(data2[:,(2*i)], data2[:,(2*i) + 1])
    plt.title('Component ' + str(i))
    plt.xlabel('data ' + str(2*i))
    plt.ylabel('data ' + str((2*i) + 1))
    plt.show()
# Out:
# 0
# 1
# 2

# %% [markdown]
# Apply K means clustering to the first scatter. After some experimentation, 3 clusters seemed to fit best.

# %%
data2 = np.load('./task2_4.npy')

predicted_labels = skcl.KMeans(n_clusters=3).fit_predict(data2)
plt.scatter(data2[:,0], data2[:,1], c=predicted_labels)
plt.title('Component 1')
plt.xlabel('data 0')
plt.ylabel('data 1')
plt.scatter(skcl.KMeans(n_clusters=3).fit(data2).cluster_centers_[:,0], skcl.KMeans(n_clusters=3).fit(data2).cluster_centers_[:,1], c='red')
plt.show()
# Out:
# c:\Users\tvern\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\tvern\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\tvern\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
data2 = np.load('./task2_4.npy')

predicted_labels = skcl.KMeans(n_clusters=5).fit_predict(data2)
plt.scatter(data2[:,4], data2[:,5], c=predicted_labels)
plt.title('Component 1')
plt.xlabel('data 4')
plt.ylabel('data 5')
plt.scatter(skcl.KMeans(n_clusters=5).fit(data2).cluster_centers_[:,4], skcl.KMeans(n_clusters=5).fit(data2).cluster_centers_[:,4], c='red')
plt.show()
# Out:
# c:\Users\tvern\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\tvern\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\tvern\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %% [markdown]
# try using elbow method
